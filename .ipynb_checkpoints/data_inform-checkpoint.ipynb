# %%
import pickle
with open('C:/Users/TobyCurtis/Desktop/final_project/result_cam_cab.pkl', 'rb') as fid:
        own_data = pickle.load(fid)

# %%
print(own_data[300])
# Out:
# [[228.24371339 322.12085632 335.         300.        ]
#  [170.05142272 406.88906381 294.         300.        ]
#  [140.71970454  39.34314792 278.         300.        ]]

# %%
import pickle
import numpy as np
data_link = 'C:/Users/TobyCurtis/Desktop/final_project/result_cam_cab.pkl'
def dump_from_tracking(data_link):
    with open(data_link, 'rb') as fid:
        own_data = pickle.load(fid)
    data = {}
    for i in own_data:
        for j in i:
            ID = j[2]
            posX = (j[0]/416)*1080
            posY = (j[1]/416)*1920
            frame = j[3]
            t = np.array([posX,posY,frame,ID], ndmin = 2)
            if ID in data:
                data[ID] = np.concatenate([data[ID],t])
            else: 
                data[ID] = t
    mydict = {u'cars':[], u'camera_calibration':{}}
    for key,i in data.items():
        posX = list(i[:,0])
        posY = list(i[:,1])
        frame = list(i[:,2])
        for j in posX:
            accept = True
            if j > 500 and accept:
                idx = posX.index(j)
                del posX[0:idx]
                del posY[0:idx]
                del frame[0:idx]
                accpet = False
        frame, posX, posY = zip(*sorted(zip(frame,posX,posY)))
        ID = i[:,3][0]
        car = {u'frames':frame, u'id': int(ID), u'posX':posX,u'posY': posY}
        mydict['cars'].append(car)

# %%
import numpy as np
a = np.array([[1,2,3],[4,5,6]], ndmin = 2)
b = [4,5,6]
d = [7,8,9]
e = np.full((2,3),2)
c = np.concatenate((a,e))
print(c)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [2 2 2]
#  [2 2 2]]

# %%
import pickle
import numpy as np
import json
data_link = 'C:/Users/ADMINS/Desktop/final_project/result_cam_cab.pkl'
def dump_from_tracking(data_link):
    with open(data_link, 'rb') as fid:
        own_data = pickle.load(fid)
    data = np.concatenate(own_data)
    data = np.asarray(sorted(data, key=lambda x: x[2]))
    mydict = {u'cars':[], u'camera_calibration':{}}
    temp = data[0,2]
    frame = []
    posX = []
    posY = []
    for i in data:
        if i[2] == temp:
            # from 100 in 1080
            if i[0] > 39:
                posX.append((i[0]/416)*1080)
                posY.append((i[1]/416)*1920)
                frame.append(i[3])
            else:
                continue
        elif i[2]!= temp:
            if len(frame) > 16:
                if np.linalg.norm(posX[0]-posX[-1]) > 100:
                    car = {u'frames':frame, u'id': int(temp), u'posX':posX,u'posY': posY}
                    mydict['cars'].append(car)
            temp = i[2]
            frame = []
            posX = []
            posY = []
    vp1 = [144.737, 34.7794]
    vp2 = [12183.582175112755, 615.451021479187]
    pp = [960.5, 540.5]
    scale = 0.01822590999670784
    mydict['camera_calibration'][u'vp1']= vp1
    mydict['camera_calibration'][u'vp2']= vp2
    mydict['camera_calibration'][u'pp'] = pp
    mydict['camera_calibration'][u'scale']= scale
    with open('C:/Users/ADMINS/Desktop/final_project/result_new.json', 'w') as f:
        json.dump(mydict, f)
    return mydict
a = dump_from_tracking(data_link)

# %%
def searchCarByID(data, ID):
    for car in data['cars']:
        if car['id'] == ID:
            return car
b = searchCarByID(a, 278)
print(b['posX'][0],b['posX'][-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-c371ac47b305> in <module>
#       4             return car
#       5 b = searchCarByID(a, 278)
# ----> 6 print(b['posX'][0],b['posX'][-1])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
vp1 = [144.737, 34.7794]
vp2 = [12183.582175112755, 615.451021479187]
# vp3 = [193.8689,1335e3]
pp = [960.5, 540.5]
# focal[463.0586]
# p -0.0116 0.9247 0.3805 10
scale = 0.01822590999670784
mydict['camera_calibration'][u'vp1']= vp1
mydict['camera_calibration'][u'vp2']= vp2
mydict['camera_calibration'][u'pp'] = pp
mydict['camera_calibration'][u'scale']= scale

# %%
print(mydict['camera_calibration'])
# Out:
# {'vp1': [144.737, 34.7794], 'vp2': [12183.582175112755, 615.451021479187], 'pp': [960.5, 540.5], 'scale': 0.01822590999670784}

# %%
import json
with open('C:/Users/TobyCurtis/Desktop/result_new.json', 'w') as f:
    json.dump(mydict, f)

# %%
import cv2
import matplotlib.pyplot as plt
import json
image = cv2.imread('C:/Users/ADMINS/Desktop/final_project/BrnoCompSpeed/code/dataset/session0_center/screen.png')
# data = json.load(open('C:/Users/TobyCurtis/Desktop/BrnoCompSpeed/code/results/session0_center/system_dubska_optimal_calib.json'))

color = (255, 0, 0) 
thickness = 20
# a = mydict["cars"][16]
# print(a)
# for key,value in data.items():
#     if key in [300,321,352,346,369]:
#         for i in value:
#             print(int(i[1]),int(i[0]))
# 1692.3056186151205, 774.4358285565627, 1] [879.8550888974346, 365.19141972821404, 1]
# 544.8441862309558, 301.2684326640012, 1] [1379.8632666341841, 878.0208415870966, 1]

image = cv2.circle(image, (544,301), 3, color, thickness)
image = cv2.circle(image, (1380,878), 3, color, thickness)
image = cv2.circle(image, (1552,802), 3, (0,0,255), thickness)
image = cv2.circle(image, (635,499), 3, (0,0,255), thickness)

# cv2.line(image, (145, 35), (1000, 523), (0,255,0), thickness)
# cv2.line(image, (145, 35), (1000, 764), (0,255,0), thickness)

cv2.imwrite("bug.jpg", image)
plt.imshow(image)

# %%
import numpy as np
l1 = np.array([-0.5561045 ,  0.83111238, 51.65539177])
l2 = np.array([-0.65281474,  0.7575176 , 71.40300615])
p = np.array([1379.8632666341841, 878.0208415870966, 1])
p = np.array([544.8441862309558, 301.2684326640012, 1])
p = np.array([1379.8632666341841, 878.0208415870966, 1]) 
print(np.dot(p,l1))
print(np.dot(p,l2))
print(np.dot(l1[0:2],l2[0:2]))
# Out:
# 14.041211151085072
# -164.27583282430794
# 0.992615470008218

# %%
import json
import cv2
import matplotlib.pyplot as plt
data = json.load(open('C:/Users/TobyCurtis/Desktop/BrnoCompSpeed/code/results/session0_center/system_dubska_optimal_calib.json'))
print(len(data['cars'][0]['posX']))
image = cv2.imread('C:/Users/TobyCurtis/Desktop/BrnoCompSpeed/code/dataset/session0_center/screen.png',0)
color = (0, 255, 0) 
thickness = 20

image = cv2.circle(image, (round(data['cars'][0]['posY'][0]),round(data['cars'][0]['posX'][0])), 3, color, thickness)
image = cv2.circle(image, (round(data['cars'][0]['posY'][15]),round(data['cars'][0]['posX'][15])), 3, color, thickness)
image = cv2.circle(image, (round(data['cars'][0]['posY'][46]),round(data['cars'][0]['posX'][46])), 3, color, thickness)
plt.imshow(image,cmap ='gray')
# Out:
# 47

# %% [markdown]
# # Detect by Yolov3-416

# %%
import cv2
import numpy as np
import time

def get_output_layers(net):
    '''
    get all output layer names: with yolov3 is yolo_82, 94 and 106
    ''' 
    layer_names = net.getLayerNames()
    
    output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

    return output_layers


def draw_prediction(img, class_id, confidences, x, y, x_plus_w, y_plus_h):
    '''
    draw a bounding box around object
    '''
    label = str(classes[class_id])

    color = COLORS[class_id]

    cv2.rectangle(img, (x,y), (x_plus_w,y_plus_h), color, 2)

    cv2.putText(img, label, (x-10,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

def bounding_pic(net, image, scale, size):
    '''
    net: the model reading by open-cv (maybe YoLo or SSD)
    image: image need to bouding box
    scale: image pixel multiply with this
    size: a tuple contain size of image
    '''
    Width = image.shape[1]
    Height = image.shape[0]
    # Resize picture to 416x416, because YOLO take in 416x416
    blob = cv2.dnn.blobFromImage(image, scale, (416,416), (0,0,0), True, crop=False)
    # set input is resized picture
    net.setInput(blob)
    # last layer of Yolo model
    outs = net.forward(get_output_layers(net))

    class_ids = []
    confidences = []
    boxes = []
    conf_threshold = 0.6
    # maybe our model will detect many bouding box for an object, this threshold help us take the box with equal 
    #            or higher propability
    nms_threshold = 0.4

    '''
    out is a 2D tensor like (number_of_objects, score_of_each_classes), with first five element in each row is special, 
    take e.g: out[0] = temp:
        + temp[0]: x_center of that object
        + temp[1]: y_center of that object
        + temp[2]: width of that object
        + temp[3]: height of that object
        + temp[4]: unknow value
        + from 5 to above is the score of that object to each classes => COCO have 80 class so each row contain 85 element,
            will be 15 with CIFAR,and 1005 with IMAGENET  
    '''
    for out in outs:
        for detection in out:
            scores = detection[5:]
            # get the highest score to determine its label
            class_id = np.argmax(scores)
            if class_id not in [0,1,2,3,7]:
                continue
            else:
                # score of that object, make sure more than 50% correct label
                confidence = scores[class_id]
                if confidence > 0.5:
                    # scale again with w and h
                    center_x = int(detection[0] * Width)
                    center_y = int(detection[1] * Height)
                    w = int(detection[2] * Width)
                    h = int(detection[3] * Height)
                    # remember it return x_center and y_center, not x,y, so we need to find x,y
                    x = center_x - w / 2
                    y = center_y - h / 2
                    class_ids.append(class_id)
                    confidences.append(float(confidence))
                    boxes.append([x, y, w, h])

    # detect bouding box around objects
    indices = cv2.dnn.NMSBoxes(boxes, confidences, conf_threshold, nms_threshold)
    # set the counting line
    lineThickness = 2
    
    for i in indices:
        i = i[0]
        box = boxes[i]
        x = box[0]
        y = box[1]
        w = box[2]
        h = box[3]
        draw_prediction(image, class_ids[i], confidences[i], round(x), round(y), round(x+w), round(y+h))
    return image,x,y

# image_path = 'motorbike.jpg'
config = 'YOLOv3-416\\yolov3.cfg'
name = 'coco.names'
weight = 'YOLOv3-416\\yolov3.weights'

# image = cv2.imread(image_path)

classes = None

with open(name, 'r') as f:
    # generate all classes of COCO, bicycle ind = 1, car ind = 2 and motorbike ind = 3
    classes = [line.strip() for line in f.readlines()]

COLORS = np.random.uniform(0, 255, size=(len(classes), 3))

# Read the model
net = cv2.dnn.readNet(weight, config)
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)
# take shape of image in order to scale it to 416x416, first layer of Yolo CNN

scale = 0.00392

t1 = time.time()

cap = cv2.VideoCapture('C:\\Users\\ADMINS\\Desktop\\video_speed measure\\front.avi')
# fourcc = cv2.VideoWriter_fourcc(*'XVID')

# outputVideo = cv2.VideoWriter('C:/Users/ADMINS/Desktop/temp.avi', fourcc, 20, (1920,1080))
frameNo = 0
count = 0
while(True):
    
    # Capture frame-by-frame
    ret, frame = cap.read()
    thresh = 1
    frameNo += 1

    if count%thresh==0:
        t2 = time.time()
        # Our operations on the frame come here
        img,x,y = bounding_pic(net, frame, scale, (416,416))
        r = [x,y,frameNo,]
        text1= 'Number of Frame: '+ str(frameNo)
        text2= 'Real time:' + str(t2-t1) + 's'
        # Display the resulting frame
        cv2.putText(frame, text1, (10, 20),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 255), 2)
        cv2.putText(frame, text2, (10, 100),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 255), 2)
        cv2.namedWindow('image',cv2.WINDOW_NORMAL)
        cv2.resizeWindow('image', 1800,800)
        cv2.imshow('image',img)
#         outputVideo.write(frame)

    count += 1
    if count == thresh*30:
        count = 0
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
# outputVideo.release()
cv2.destroyAllWindows()

# %%
import json
import numpy as np
import cv2

# data = json.load(open('C:/Users/TobyCurtis/Desktop/final_project/result.json'))
import pickle
with open('C:/Users/ADMINS/Desktop/final_project/result_cam_cab.pkl', 'rb') as fid:
    own_data = pickle.load(fid)
own_data = np.concatenate(own_data)
dict_package = {}
for package in own_data:
    if package[3] in dict_package.keys():
        dict_package[package[3]].append(package[:3])
    else:
        dict_package[package[3]] = [package[:3]]

# %%
def showSpeeds(video_path, data):
    cap = cv2.VideoCapture(video_path)
    frame_width = int(cap.get(3))
    frame_height = int(cap.get(4))
    out = cv2.VideoWriter('C:/Users/ADMINS/Desktop/outpy.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 25, (frame_width,frame_height))
    window_name = 'frame'
    cv2.namedWindow(window_name,cv2.WINDOW_NORMAL)
    font = cv2.FONT_HERSHEY_SIMPLEX 
    org = (50, 50) 
    fontScale = 1
    color = (255, 0, 0) 
    thickness = 3
    if (cap.isOpened()==False):
        print('Please check the video_path!!!')
    frame_num = 0    
    while(cap.isOpened()):
        ret,frame = cap.read()
        if frame_num in data.keys():
            for package in data[frame_num]:
#                 print(package)
                frame = cv2.putText(frame, 'ID: '+str(int(package[2])), (int(package[1]*1920/416),int(package[0]*1080/416)),
                                    font,fontScale, color, thickness, cv2.LINE_AA) 
#                 frame = cv2.putText(frame, 'Speed: '+str(package[3]), (int(package[1])+20,int(package[0])+20), font,  
#                        fontScale, color, thickness, cv2.LINE_AA)
        cv2.resizeWindow(window_name, 900,600)
        out.write(frame)
#         cv2.imshow(window_name, frame)
        frame_num+=1
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
    cap.release()
    out.release()
    cv2.destroyAllWindows()
# video = 'C:/Users/TobyCurtis/Desktop/front.avi'
video = 'Z:/Vehicle speed measuring/video_speed measure/front.avi'
showSpeeds(video,dict_package)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ff63aea66e31> in <module>
#      34 # video = 'C:/Users/TobyCurtis/Desktop/front.avi'
#      35 video = 'Z:/Vehicle speed measuring/video_speed measure/front.avi'
# ---> 36 showSpeeds(video,dict_package)
#
# <ipython-input-3-ff63aea66e31> in showSpeeds(video_path, data)
#      24 #                        fontScale, color, thickness, cv2.LINE_AA)
#      25         cv2.resizeWindow(window_name, 900,600)
# ---> 26         out.write(frame)
#      27 #         cv2.imshow(window_name, frame)
#      28         frame_num+=1
#
# KeyboardInterrupt:

# %%
import itertools
import random
from itertools import starmap

import cv2
import numpy as np


'''
This function return a list with each element is a tuple contain 2 points of 1 lines.
'''
def hough_transform(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert image to grayscale
    kernel = np.ones((15, 15), np.uint8)

    opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN, kernel)  # Open (erode, then dilate)
    edges = cv2.Canny(opening, 50, 150, apertureSize=3)  # Canny edge detection
    lines = cv2.HoughLines(edges, 1, np.pi / 180, 200)  # Hough line detection
    
    hough_lines = []
    # Lines are represented by rho, theta; converted to endpoint notation
    if lines is not None:
        for line in lines:
            hough_lines.extend(list(starmap(endpoints, line)))
            
    return hough_lines

# %%
from matplotlib import pyplot as plt
img = 'C:/Users/ADMINS/Desktop/final_project/BrnoCompSpeed/code/dataset/session0_center/screen.png'
img = cv2.imread(img)
wines = hough_transform(img)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convert image to grayscale
kernel = np.ones((15, 15), np.uint8)

opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN, kernel)  # Open (erode, then dilate)
edges = cv2.Canny(opening, 50, 150, apertureSize=3)  # Canny edge detection
lines = cv2.HoughLines(edges, 1, np.pi / 180, 200)  # Hough line detection

hough_lines = []
# Lines are represented by rho, theta; converted to endpoint notation
if lines is not None:
    for line in lines:
#         print(list(starmap(endpoints,line)))
        hough_lines.extend(list(starmap(endpoints, line)))
color = (255,0,0)
thickness = 5

for i in hough_lines:
    img = cv2.line(img, (i[0]),(i[1]), color, thickness)
plt.imshow(img, cmap = 'Greys')

# %%
# look into your book, remember the time at vnpt

def endpoints(rho, theta):
    a = np.cos(theta)
    b = np.sin(theta)
    x_0 = a * rho
    y_0 = b * rho
    x_1 = int(x_0 + 1000 * (-b))
    y_1 = int(y_0 + 1000 * (a))
    x_2 = int(x_0 - 1000 * (-b))
    y_2 = int(y_0 - 1000 * (a))

    return ((x_1, y_1), (x_2, y_2))

# %%
# Random sampling of lines
def sample_lines(lines, size):
    if size > len(lines):
        size = len(lines)
    return random.sample(lines, size)

# %%
def det(a, b):
    return a[0] * b[1] - a[1] * b[0]

# %%
# Find intersection point of two lines (not segments!)
def line_intersection(line1, line2):
    x_diff = (line1[0][0] - line1[1][0], line2[0][0] - line2[1][0])
    y_diff = (line1[0][1] - line1[1][1], line2[0][1] - line2[1][1])

    div = det(x_diff, y_diff)
    if div == 0:
        return None  # Lines don't cross

    d = (det(*line1), det(*line2))
    x = det(d, x_diff) / div
    y = det(d, y_diff) / div

    return x, y

# %%
for k,v in enumerate(hough_lines):
    try:
        a = line_intersection(hough_lines[k],hough_lines[k+1])
        if a == None:
            print('ok')
        else:
            print(a)
    except:
        pass
# Out:
# (358.3086356008778, 145.58951852329935)
# (27.90832912852303, -29.999992791753765)
# (622.6607155147494, 341.2377799496194)
# (122.11696385969023, 16.003802889739056)
# (156.49753388220998, 34.27517664674956)
# (89.04893350841097, -11.205845800721677)
# (1260.1923044035914, 414.721162890124)
# (-111.00341165058121, -111.41824369872248)
# (150.2643664317776, 27.431147712752058)
# (134.29445048966267, 22.852883569096843)
# (548.2061019567457, 271.4898300720906)
# (1314.024588053553, 768.7923532440783)
# (-167.57299176107105, -156.87834706488155)
# (182.17647505505354, 53.21634140785177)
# (1496.8574976715306, 506.0509158646383)
# (170.21232764851698, 23.827046186235812)
# (72.14802721289, 20.489522447685946)
# (457.67831121729677, 208.42749061010127)
# (542.7315457549048, 265.81404233795024)
# (114.6716481246472, 57.14377504573787)

# %%
# Find intersections between multiple lines (not line segments!)
def find_intersections(lines):
    intersections = []
    for i, line_1 in enumerate(lines):
        for line_2 in lines[i + 1:]:
            if not line_1 == line_2:
                intersection = line_intersection(line_1, line_2)
                if intersection:  # If lines cross, then add
                    intersections.append(intersection)

    return intersections

# %%
# Given intersections, find the grid where most intersections occur and treat as vanishing point
def find_vanishing_point(img, grid_size, intersections):
    # Image dimensions
    image_height = img.shape[0]
    image_width = img.shape[1]

    # Grid dimensions
    grid_rows = (image_height // grid_size) + 1
    grid_columns = (image_width // grid_size) + 1

    # Current cell with most intersection points
    max_intersections = 0
    best_cell = (0.0, 0.0)

    for i, j in itertools.product(range(grid_columns),range(grid_rows)):
        cell_left = i * grid_size
        cell_right = (i + 1) * grid_size
        cell_bottom = j * grid_size
        cell_top = (j + 1) * grid_size
        cv2.rectangle(img, (cell_left, cell_bottom), (cell_right, cell_top), (0, 0, 255), 10)

        current_intersections = 0  # Number of intersections in the current cell
        for x, y in intersections:
            if cell_left < x < cell_right and cell_bottom < y < cell_top:
                current_intersections += 1

        # Current cell has more intersections that previous cell (better)
        if current_intersections > max_intersections:
            max_intersections = current_intersections
            best_cell = ((cell_left + cell_right) / 2, (cell_bottom + cell_top) / 2)
            print("Best Cell:", best_cell)

    if best_cell[0] != None and best_cell[1] != None:
        rx1 = int(best_cell[0] - grid_size / 2)
        ry1 = int(best_cell[1] - grid_size / 2)
        rx2 = int(best_cell[0] + grid_size / 2)
        ry2 = int(best_cell[1] + grid_size / 2)
        cv2.rectangle(img, (rx1, ry1), (rx2, ry2), (0, 255, 0), 10)
        cv2.imwrite('/pictures/output/center.jpg', img)

    return best_cell

# %%
import os

import cv2

# from src.vanishing_point import hough_transform, find_intersections, sample_lines, find_vanishing_point

# for subdir, dirs, files in os.walk('C:/Users/ADMINS/Desktop/final_project/BrnoCompSpeed/code/dataset/session0_center/screen.png'):
#     for file in files:
#         filepath = subdir + os.sep + file
#         if filepath.endswith(".jpg"):
#             print(filepath)
filepath = 'C:/Users/ADMINS/Desktop/final_project/BrnoCompSpeed/code/dataset/session0_center/screen.png'
img = cv2.imread(filepath)
hough_lines = hough_transform(img)
if hough_lines:
    random_sample = sample_lines(hough_lines, 100)
    intersections = find_intersections(random_sample)
    print(intersections)
    if intersections:
        grid_size = min(img.shape[0], img.shape[1]) // 3
        vanishing_point = find_vanishing_point(img, grid_size, intersections)
#         filename = '../pictures/output/' + os.path.splitext(file)[0] + '_center' + '.jpg'
        filename = 'image.jpg'
        cv2.imwrite(filename, img)
# Out:
# [(32.902764592710774, -31.62535238720902), (446.7424863676713, 226.93291626157162), (35.224926134837496, -30.174515175933387), (132.4335243207901, 30.559352363254703), (389.12006370112124, 190.93165041857662), (-2.6117109857641685, -53.81404243889337), (78.75557346226162, -2.977491270480795), (273.1337723545742, 118.46587901091097), (385.0337529097336, 188.3786102250194), (118.86070532064528, 22.079343324226166), (965.1001946565702, 550.7918030332199), (108.06202625077965, 15.332557993849942), (-167.57299176107105, -156.87834706488155), (54.11149925015862, -18.374585424237182), (8072.0, 4991.031858407079), (-69.0379291621747, -95.31573273318172), (152.13609259908804, 42.8690985619081), (-234.0521369721936, -198.413105046344), (1314.024588053553, 768.7923532440783), (182.49674395122636, 61.83778869873081), (69.04267719788457, -18.481816546243255), (31.610819880266657, -32.09521300414157), (-46.07271991670141, -60.347533388235924), (-362.17583782735767, -175.3094234483947), (52.66139813584285, -24.439438271149804), (7.392354186261057, -40.9031001548369), (-233.53609461506977, -128.5251078924881), (89.04893350841097, -11.205845800721677), (186.94216002522373, 24.396429870728337), (182.56388493118416, 22.804117895633002), (362.90038424453496, 88.38975635730425), (53.26893189749804, -24.21848749414741), (28663.81112737921, 10381.0), (14.696403570020223, -38.24672862709062), (1260.1923044035914, 414.721162890124), (1770.1494464944649, 600.1848093480935), (60.02249361625112, -21.76231994680537), (143.19519400367435, 8.486324549792108), (315.1321256726439, 71.01716817594026), (122.11696385969023, 16.003802889739056), (188.3226476416208, 59.02169646880969), (397.9907622806425, 195.25593086134828), (92.26954231036267, -3.389897627693952), (156.4561039094621, 38.3160484232722), (299.86001018911236, 131.49436222908315), (322.2250535143536, 146.02630267131923), (132.16421046301048, 22.53211527101337), (1484.093065877769, 900.9632152391947), (131.36568278239577, 22.01326285801252), (145.24659751655983, 31.032544567740835), (88.37610687691829, -5.919701438565627), (622.6607155147494, 341.2377799496194), (-20.6057390230008, -76.73189128642474), (176.24228080079905, 51.172341164719676), (112.61973120913292, 9.832868309514174), (-54607.21487603306, -35545.0), (193.86785233107477, 62.6247560790814), (541.4842161123303, 238.8743312823602), (1140.398993158642, 557.164450755131), (778.1870616582763, 364.66881803708964), (156.49753388220998, 34.27517664674956), (134.55409827467471, 22.613452794133075), (359.3220040858798, 142.06517837538544), (135.8364210949741, 23.294936536592473), (105.73192257546886, 7.296058569852573), (64.60701750606366, -14.559556702159936), (-15.899228717652996, -57.344179341166296), (-134.90711678532085, -120.59029775899772), (210.48779666722774, 62.96801885204511), (128.844807083399, 19.57927991174406), (301.9294646463778, 111.56421407269258), (212.23357605904098, 63.89580416055549), (1750.1722817434706, 854.4162041220258), (700.699582634138, 319.9570586463577), (358.3086356008778, 145.58951852329935), (1019.181403554064, 482.1485306140011), (208.23662978709433, 69.16317979612272), (115.5615589582503, 21.967060064645157), (383.7429171812501, 158.54229415125988), (95.41395784088418, 11.706602898193125), (211.43547415740005, 70.79223754113522), (-7.952801180739192, -40.93441362769817), (91.67531483024099, 9.80264489108848), (-254.39614538447896, -166.43924978311196), (165.94466103940346, 47.625383246905635), (228.94170090121094, 79.70753661841567), (339.85265610438023, 136.1905441250269), (195.63826898219838, 62.74728240699267), (1220.7218493180155, 596.3201669463448), (1047.9884041134203, 512.1162170302483), (388.0367887208563, 190.40357647160272), (37.028285337323375, 19.294255957426422), (542.7315457549048, 265.81404233795024), (-84.11643560073537, -39.761267438088026), (507.50923176242736, 248.64389928986444), (-316.86459430602434, -153.22113779191838), (355.9645970519157, 174.76905231913085), (-675.2296961754664, -327.91 ...
# Best Cell: (180.0, 180.0)
